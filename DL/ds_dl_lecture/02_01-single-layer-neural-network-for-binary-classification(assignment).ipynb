# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate Dataset

# %%
x1 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x1.shape)
x1[0:10]
# Out:
# (100,)
# array([-0.66428062,  0.88832273, -0.68510462, -0.04022803, -0.26006973,
#        -0.02689225,  0.3941346 , -0.92522288,  0.58539962,  0.10352308])

# %%
x2 = np.random.uniform(low=-1.0, high=1.0, size=100)

print(x2.shape)
x2[0:10]
# Out:
# (100,)
# array([-0.80010615,  0.8798324 ,  0.33024211, -0.76570385, -0.93722752,
#        -0.66085214, -0.14278066,  0.87563875, -0.37470386,  0.02731991])

# %%
y = 0.3 * x1 + 0.5 * x2 + 0.1

print(y.shape)
y[0:10]
# Out:
# (100,)
# array([-0.49933726,  0.80641302,  0.05958967, -0.29492033, -0.44663468,
#        -0.23849374,  0.14685005,  0.26025251,  0.08826796,  0.14471688])

# %%
plt.scatter(x1, x2, c=y)

# %% [markdown]
# ### Gradient Descent

# %%
num_epoch = 100
learning_rate = 1.0

w1 = np.random.uniform(low=-1.0, high=1.0)
w2 = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

for epoch in range(num_epoch):
    y_predict = w1 * x1 + w2 * x2 + b
    
    error = np.abs(y_predict - y).mean()
    
    if epoch % 10 == 0:
        print("{0:2} error = {1:.6f}".format(epoch, error))
    
    if error < 0.001:
        break

    w1 = w1 - learning_rate * ((y_predict - y) * x1).mean()
    w2 = w2 - learning_rate * ((y_predict - y) * x2).mean()
    b = b - learning_rate * (y_predict - y).mean()

print("----" * 10)
print("w1 = {0:.6f}, w2 = {1:.6f} b = {2:.6f}".format(w1, w2, b))
print("{0:2} error = {1:.6f}".format(epoch, error))
# Out:
#  0 error = 0.852887
# 10 error = 0.017332
# ----------------------------------------
# w1 = 0.299886, w2 = 0.497963 b = 0.099997
# 18 error = 0.000946

# %%
import pandas as pd

y_predict = w1 * x1 + w2 * x2 + b

result = pd.DataFrame({'x1': x1, 'x2': x2, 'y(actual)': y, 'y(predict)': y_predict})

result
# Out:
#           x1        x2  y(actual)  y(predict)
# 0  -0.664281 -0.800106  -0.499337   -0.497635
# 1   0.888323  0.879832   0.806413    0.804517
# 2  -0.685105  0.330242   0.059590    0.058993
# 3  -0.040228 -0.765704  -0.294920   -0.293359
# 4  -0.260070 -0.937228  -0.446635   -0.444699
# 5  -0.026892 -0.660852  -0.238494   -0.237148
# 6   0.394135 -0.142781   0.146850    0.147093
# 7  -0.925223  0.875639   0.260253    0.258572
# 8   0.585400 -0.374704   0.088268    0.088961
# 9   0.103523  0.027320   0.144717    0.144647
